# %% [markdown]
# <a href="https://colab.research.google.com/github/Rs-Biranchi/FlipRobo/blob/master/Image_reading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

# %%
#loading a single image using opencv
path1="/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Image_Classification_Project/Scraped_images/img101_1.jpeg"
img1=cv2.imread(path1)
img1
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 252],
#         [255, 255, 251],
#         [255, 255, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 252],
#         [255, 255, 251],
#         [255, 255, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 252],
#         [255, 255, 251],
#         [255, 255, 252]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
plt.imshow(img1)

# %%
#loading all images using opencv
path="/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Image_Classification_Project/Scraped_images/*.jpeg"
all_img=cv2.imread(path)
len(all_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-9ab5677a92eb> in <module>()
#       2 path="/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Image_Classification_Project/Scraped_images/*.jpeg"
#       3 all_img=cv2.imread(path)
# ----> 4 len(all_img)
#
# TypeError: object of type 'NoneType' has no len()

# %%
#reading images by skimage

# %%
#Skimage.io
#module link- https://scikit-image.org/docs/dev/api/skimage.io.html
from skimage.io import imread_collection, imread

# %%
path=path1
#path of a single image
#path1="/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Image_Classification_Project/Scraped_images/img101_1.jpeg"
col=imread(path)

# %%
print(col.shape,"\n")

print(len(col),'\n')

print(col[0].shape,'\n')

print(col)
# Out:
# (320, 263, 3)
#
# 320
#
# (263, 3)
#
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [254 254 255]
#   [248 255 255]
#   [251 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [252 255 255]
#   [248 255 255]
#   [251 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [254 255 255]
#   [248 255 255]
#   [251 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
plt.imshow(col)
plt.show()

# %%
# Creating a collection with the available images
all_col=imread_collection("/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Image_Classification_Project/Scraped_images/*.jpeg")

# %%
len(all_col)
# Out:
# 736

# %%
from skimage.io import imshow_collection
imshow_collection(all_col[:15])

# %%
imshow_collection(all_col[700:720])

# %%
 plt.imshow(all_col[5])

# %%
all_col.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-9da9caa3b18c> in <module>()
# ----> 1 all_col.shape
#
# AttributeError: 'ImageCollection' object has no attribute 'shape'

# %%
all_col[0].shape
# Out:
# (320, 163, 3)

# %%
image2=all_col[0]
image2.shape
# Out:
# (320, 163, 3)
